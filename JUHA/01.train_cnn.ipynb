# %% [markdown]
# ## 1. 데이터 준비 및 진행 구조

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# 입력
x = torch.tensor([
    [1.0],
    [2.0],
    [3.0],
    [4.0]
])

# 정답
y = torch.tensor([
    [2.0],
    [4.0],
    [6.0],
    [8.0]
])

# 선형 모델
model = nn.Linear(1, 1)

# MSE
criterion = nn.MSELoss()

# SGD
optimizer = optim.SGD(
    model.parameters(),
    lr=0.01
)

for epoch in range(1000):

    # 예측
    prediction = model(x)

    # Loss
    loss = criterion(prediction, y)

    # 기존 gradient 삭제
    optimizer.zero_grad()

    # 미분
    loss.backward()

    # 가중치 업데이트
    optimizer.step()

print("weight:", model.weight.item())
print("bias:", model.bias.item())
print("loss:", loss.item())
# Out:
# weight: 1.9918789863586426
# bias: 0.023877007886767387
# loss: 9.578987373970449e-05

# %% [markdown]
# 5. CNN 학습
#
# 이제 실제 사진을 학습시키자.
#
# 먼저 필요한 라이브러리:

# %%
pip install torch torchvision opencv-python pillow
# Out:
# Requirement already satisfied: torch in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (2.14.0)
# Requirement already satisfied: torchvision in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (0.29.0)
# Requirement already satisfied: opencv-python in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (5.0.0.93)
# Requirement already satisfied: pillow in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (12.3.0)
# Requirement already satisfied: filelock in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from torch) (3.32.6)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from torch) (4.16.0)
# Requirement already satisfied: setuptools>=77.0.3 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from torch) (84.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from torch) (2026.7.0)
# Requirement already satisfied: cuda-toolkit==13.0.3 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch) (13.0.3.0)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from torch) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.24.0.43 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from torch) (9.24.0.43)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from torch) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.30.7 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from torch) (2.30.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from torch) (3.4.5)
# Requirement already satisfied: triton~=3.8.0 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from torch) (3.8.0)
# Requirement already satisfied: nvidia-cublas==13.1.1.3.* in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch) (13.1.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch) (13.0.88)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch) (12.0.0.61)
# Requirement already satisfied: nvidia-nvjitlink<14,>=13.0.88 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch) (13.3.33)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch) (12.6.3.3)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch) (13.0.85)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch) (1.8.1)
# Requirement already satisfied: numpy in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from torchvision) (2.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/user14/Documents/GitHub/DeepLearningProject/.venv/lib/python3.12/site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split


# =========================
# 1. 이미지 전처리
# =========================

transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor()
])


# =========================
# 2. 데이터 불러오기
# =========================

dataset = datasets.ImageFolder(
    "../dataset",
    transform=transform
)

print("클래스:", dataset.classes)
print("전체 이미지:", len(dataset))


# =========================
# 3. 학습 / 검증 데이터 분리
# =========================

train_size = int(len(dataset) * 0.8)
val_size = len(dataset) - train_size

train_dataset, val_dataset = random_split(
    dataset,
    [train_size, val_size]
)

train_loader = DataLoader(
    train_dataset,
    batch_size=4,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=4,
    shuffle=False
)


# =========================
# 4. CNN
# =========================

class CNN(nn.Module):

    def __init__(self, num_classes):

        super().__init__()

        self.features = nn.Sequential(

            nn.Conv2d(3, 16, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(16, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        self.classifier = nn.Sequential(

            nn.Flatten(),

            nn.Linear(64 * 16 * 16, 128),
            nn.ReLU(),

            nn.Linear(128, num_classes)
        )

    def forward(self, x):

        x = self.features(x)
        x = self.classifier(x)

        return x


# =========================
# 5. 모델 생성
# =========================

num_classes = len(dataset.classes)

model = CNN(num_classes)

print(model)


# =========================
# 6. Loss / Optimizer
# =========================

criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(
    model.parameters(),
    lr=0.001
)


# =========================
# 7. 학습
# =========================

epochs = 20

for epoch in range(epochs):

    model.train()

    total_loss = 0

    for images, labels in train_loader:

        prediction = model(images)

        loss = criterion(
            prediction,
            labels
        )

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()

        total_loss += loss.item()

    print(
        f"Epoch {epoch + 1}/{epochs} "
        f"Loss: {total_loss:.4f}"
    )


# =========================
# 8. 모델 저장
# =========================

torch.save(
    {
        "model_state": model.state_dict(),
        "classes": dataset.classes
    },
    "models/object_cnn.pth"
)

print("학습 완료!")
print("모델 저장 완료!")
# Out:
# 클래스: ['nipper', 'pen', 'scraper']
# 전체 이미지: 207
# CNN(
#   (features): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=16384, out_features=128, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=128, out_features=3, bias=True)
#   )
# )
# Epoch 1/20 Loss: 44.2999
# Epoch 2/20 Loss: 23.0070
# Epoch 3/20 Loss: 15.7352
# Epoch 4/20 Loss: 12.0035
# Epoch 5/20 Loss: 10.9443
# Epoch 6/20 Loss: 6.3786
# Epoch 7/20 Loss: 5.1745
# Epoch 8/20 Loss: 6.7281
# Epoch 9/20 Loss: 6.3066
# Epoch 10/20 Loss: 4.9916
# Epoch 11/20 Loss: 4.1299
# Epoch 12/20 Loss: 1.2112
# Epoch 13/20 Loss: 3.1874
# Epoch 14/20 Loss: 3.5767
# Epoch 15/20 Loss: 0.6395
# Epoch 16/20 Loss: 0.4550
# Epoch 17/20 Loss: 0.2378
# Epoch 18/20 Loss: 0.3839
# Epoch 19/20 Loss: 0.9579
# Epoch 20/20 Loss: 3.0543
# 학습 완료!
# 모델 저장 완료!

# %%
import os
import torch

# models 폴더 자동 생성
os.makedirs("models", exist_ok=True)

# 모델 저장
torch.save(
    {
        "model_state": model.state_dict(),
        "classes": dataset.classes
    },
    "models/object_cnn.pth"
)

print("🎉 학습 완료!")
print("💾 모델 저장 완료!")
print("클래스:", dataset.classes)
# Out:
# 🎉 학습 완료!
# 💾 모델 저장 완료!
# 클래스: ['nipper', 'pen', 'scraper']

# %% [markdown]
# 이 코드에서:
#
# nn.Conv2d(3, 16, 3, padding=1)
#
# 의 3은 RGB 이미지의 채널 수야.
#
# 그리고:
#
# nn.MaxPool2d(2)
#
# 를 거치면서 이미지 크기를 줄이고 특징을 압축해.
#
# 마지막:
#
# nn.Linear(128, num_classes)
#
# 에서 최종적으로
#
# 스크래퍼
# 렌치
#
# 중 어느 것인지 판단한다.

# %%
nn.Conv2d(3, 16, 3, padding=1)
# Out:
# Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))

# %%
nn.MaxPool2d(2)
# Out:
# MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)

# %%
nn.Linear(128, num_classes)
# Out:
# Linear(in_features=128, out_features=3, bias=True)

# %% [markdown]
# ## 새로운 데이터를 입력했을 경우
#
# 이 학습 코드부터 다시 실행
#
# 노트북에서 아래 셀을 처음부터 다시 실행하면 돼.

# %%
import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split

# %% [markdown]
# 그 다음 데이터 불러오는 부분:

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor()
])

dataset = datasets.ImageFolder(
    "../dataset",
    transform=transform
)

print("클래스:", dataset.classes)
print("전체 이미지:", len(dataset))
# Out:
# 클래스: ['nipper', 'pen', 'scraper']
# 전체 이미지: 207

# %% [markdown]
# 여기서 아주 중요해.
#
# 실행했을 때 예를 들어:
#
# 클래스: ['nipper', 'scraper', 'screwdriver', 'wrench']
# 전체 이미지: 120
#
# 이렇게 새로 추가한 물건까지 나오는지 확인해.

# %%
## 학습 데이터 나누기

# %%
train_size = int(len(dataset) * 0.8)
val_size = len(dataset) - train_size

train_dataset, val_dataset = random_split(
    dataset,
    [train_size, val_size]
)

train_loader = DataLoader(
    train_dataset,
    batch_size=4,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=4,
    shuffle=False
)

# %% [markdown]
# ## CNN 모델 다시 생성

# %%
class CNN(nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3, 16, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(16, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 16 * 16, 128),
            nn.ReLU(),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
num_classes = len(dataset.classes)

model = CNN(num_classes)

print("클래스 개수:", num_classes)
print("클래스:", dataset.classes)
# Out:
# 클래스 개수: 3
# 클래스: ['nipper', 'pen', 'scraper']

# %% [markdown]
# ## 실제 학습 실행

# %%
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(
    model.parameters(),
    lr=0.001
)

epochs = 20

for epoch in range(epochs):

    model.train()

    total_loss = 0

    for images, labels in train_loader:

        prediction = model(images)

        loss = criterion(
            prediction,
            labels
        )

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()

        total_loss += loss.item()

    print(
        f"Epoch {epoch + 1}/{epochs} "
        f"Loss: {total_loss:.4f}"
    )
# Out:
# Epoch 1/20 Loss: 43.4926
# Epoch 2/20 Loss: 29.8770
# Epoch 3/20 Loss: 16.5146
# Epoch 4/20 Loss: 10.7730
# Epoch 5/20 Loss: 10.7686
# Epoch 6/20 Loss: 6.1260
# Epoch 7/20 Loss: 4.6042
# Epoch 8/20 Loss: 3.3625
# Epoch 9/20 Loss: 3.6810
# Epoch 10/20 Loss: 3.1909
# Epoch 11/20 Loss: 0.2579
# Epoch 12/20 Loss: 3.0069
# Epoch 13/20 Loss: 4.8772
# Epoch 14/20 Loss: 1.0450
# Epoch 15/20 Loss: 0.6540
# Epoch 16/20 Loss: 0.1407
# Epoch 17/20 Loss: 3.5244
# Epoch 18/20 Loss: 6.5957
# Epoch 19/20 Loss: 1.8799
# Epoch 20/20 Loss: 0.7155

# %% [markdown]
# ## ⭐ 학습이 끝나면 모델 저장

# %%
import os

os.makedirs("models", exist_ok=True)

torch.save(
    {
        "model_state": model.state_dict(),
        "classes": dataset.classes
    },
    "models/object_cnn.pth"
)

print("학습 완료!")
print("모델 저장 완료!")
# Out:
# 학습 완료!
# 모델 저장 완료!
